# %%
import pandas as pd
import matplotlib.pyplot as plt

# अगर आपने अपनी फाइल लोड की है (उदाहरण के लिए)
# df = pd.read_csv("sales_data.csv") 

# इसके ठीक नीचे आपका ग्राफ वाला कोड आएगा:
plt.figure(figsize=(8, 5)) # चौड़ाई 8 और ऊँचाई 5 इंच
plt.bar(df["Name"], df["Score"], color='lightgreen')
plt.title("Students Performance")
plt.xlabel("Student Names")
plt.ylabel("Scores")
plt.savefig("student_chart.png")
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()
